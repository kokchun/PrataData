# %%
from story_charts import StoryChart
import pandas as pd

df = pd.read_csv("../data/co2_annmean_mlo.csv", skiprows=43)

sc = StoryChart()

title = "The annual mean of CO$_2$ emissions measured in Mauna Loa has \nincreased every year since 1959"
sc.Line(
    df["year"],
    df["mean"],
    title=title,
    xlabel="YEARS FROM 1959",
    ylabel="CO$_2$ MOLE FRACTON IN PPM",
)

# %%
df = pd.read_html("https://www.worldometers.info/co2-emissions/co2-emissions-by-country/", index_col=0)[0]
df = df.rename({"Share  of world": "World percentage"}, axis=1)
df["World percentage"] = df["World percentage"].str.rstrip("%").astype(float)
dff = df.head(8)
dff
# Out:
#          Country  CO2 Emissions  (tons, 2016) 1 Year  Change  \
# #
# 1          China                  10432751400         -0.28%
# 2  United States                   5011686600         -2.01%
# 3          India                   2533638100          4.71%
# 4         Russia                   1661899300         -2.13%
# 5          Japan                   1239592060         -1.21%
# 6        Germany                    775752190          1.28%
# 7         Canada                    675918610         -1.00%
# 8           Iran                    642560030          2.22%
#
#    Population  (2016)  Per  capita  World percentage
# #
# 1          1401889681         7.44             29.18
# 2           327210198        15.32             14.02
# 3          1338636340         1.89              7.09
# 4           145109157        11.45              4.65
# 5           126993857         9.76              3.47
# 6            82331423         9.42              2.17
# 7            36113532        18.72              1.89
# 8            83306231         7.71              1.80

# %%
number_countries = 8
top_emitter = 3
red, gray = "#be123c", "#4b5563"
colors = [red] * top_emitter + [gray] * (number_countries - top_emitter)


sc.Bar(
    x=dff["Country"],
    y=dff["World percentage"],
    title="The top three CO$_2$ emitters in the world stand for more \nthan 50% of the worlds total CO$_2$ emissions.",
    xlabel="TOP 8 CO$_2$ EMITTERS IN THE WORLD",
    ylabel="% OF THE WORLDS CO$_2$",
    colors= colors
)
